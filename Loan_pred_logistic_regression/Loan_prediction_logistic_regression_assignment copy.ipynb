# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import seaborn as sns

from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, precision_score, classification_report

# %%
train= pd.read_csv('train_loan.csv')
test= pd.read_csv('test_loan.csv')

# %%
test.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 test.head()
#
# NameError: name 'test' is not defined

# %%
train.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
train.shape
# Out:
# (614, 13)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
train.isna().sum().sort_values(ascending=False)
# Out:
# Credit_History       50
# Self_Employed        32
# LoanAmount           22
# Dependents           15
# Loan_Amount_Term     14
# Gender               13
# Married               3
# Loan_ID               0
# Education             0
# ApplicantIncome       0
# CoapplicantIncome     0
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
test.isna().sum().sort_values(ascending=False)
# Out:
# Credit_History       29
# Self_Employed        23
# Gender               11
# Dependents           10
# Loan_Amount_Term      6
# LoanAmount            5
# Loan_ID               0
# Married               0
# Education             0
# ApplicantIncome       0
# CoapplicantIncome     0
# Property_Area         0
# dtype: int64

# %%
train.duplicated().sum()
# Out:
# 0

# %%
train.Credit_History.value_counts(dropna=False)
# Out:
# 1.0    475
# 0.0     89
# NaN     50
# Name: Credit_History, dtype: int64

# %%
train.dropna(subset=['Credit_History'],inplace=True)
test.dropna(subset=['Credit_History'], inplace=True)

# %%
test.isna().sum().sort_values(ascending=False)
# Out:
# Self_Employed        22
# Gender               11
# Dependents            8
# LoanAmount            5
# Loan_Amount_Term      5
# Loan_ID               0
# Married               0
# Education             0
# ApplicantIncome       0
# CoapplicantIncome     0
# Credit_History        0
# Property_Area         0
# dtype: int64

# %%
train.isna().sum().sort_values(ascending=False)
# Out:
# Self_Employed        26
# LoanAmount           21
# Dependents           15
# Loan_Amount_Term     14
# Gender               12
# Married               3
# Loan_ID               0
# Education             0
# ApplicantIncome       0
# CoapplicantIncome     0
# Credit_History        0
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
train.dropna(subset=['LoanAmount'],inplace=True)
test.dropna(subset=['LoanAmount'], inplace=True)

# %%
test
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# 5    LP001054   Male     Yes          0  Not Graduate           Yes
# ..        ...    ...     ...        ...           ...           ...
# 361  LP002969   Male     Yes          1      Graduate            No
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# ...

# %%
train.isna().sum().sort_values(ascending=False)
# Out:
# Self_Employed        31
# Loan_Amount_Term     14
# Gender               13
# Dependents           13
# Married               2
# Loan_ID               0
# Education             0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Credit_History        0
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
train.dropna(subset=['Married'],inplace=True)
test.dropna(subset=['Married'], inplace=True)

# %%
train['Gender'].fillna(train['Gender'].mode()[0], inplace=True)
test['Gender'].fillna(test['Gender'].mode()[0], inplace=True)

# %%
train['Dependents'].fillna(train['Dependents'].mode()[0], inplace=True)
test['Dependents'].fillna(test['Dependents'].mode()[0], inplace=True)

# %%
train['Self_Employed'].fillna(train['Self_Employed'].mode()[0], inplace=True)
test['Self_Employed'].fillna(test['Self_Employed'].mode()[0], inplace=True)

# %%
train['Loan_Amount_Term'].fillna(train['Loan_Amount_Term'].mode()[0], inplace=True)
test['Loan_Amount_Term'].fillna(test['Loan_Amount_Term'].mode()[0], inplace=True)

# %%
train["Dependents"].value_counts()
# Out:
# 0     317
# 2      92
# 1      86
# 3+     46
# Name: Dependents, dtype: int64

# %%
train['Dependents'].replace({0:0,1:1,2:2,'3+':3}, inplace = True)
test['Dependents'].replace({0:0,1:1,2:2,'3+':3}, inplace = True)

# %%
test.isna().sum().sort_values(ascending=False)
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# dtype: int64

# %%
test
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# 5    LP001054   Male     Yes          0  Not Graduate           Yes
# ..        ...    ...     ...        ...           ...           ...
# 361  LP002969   Male     Yes          1      Graduate            No
# 362  LP002971   Male     Yes          3  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# ...

# %%
train.drop(labels="Loan_ID", axis=1,inplace=True)

# %%
test.drop(labels="Loan_ID", axis=1,inplace=True)

# %%
train["Dependents"]=train["Dependents"].astype(int)

# %%
test["Dependents"]=test["Dependents"].astype(int)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 541 entries, 1 to 613
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             541 non-null    object
#  1   Married            541 non-null    object
#  2   Dependents         541 non-null    int64
#  3   Education          541 non-null    object
#  4   Self_Employed      541 non-null    object
#  5   ApplicantIncome    541 non-null    int64
#  6   CoapplicantIncome  541 non-null    float64
#  7   LoanAmount         541 non-null    float64
#  8   Loan_Amount_Term   541 non-null    float64
#  9   Credit_History     541 non-null    float64
#  10  Property_Area      541 non-null    object
#  11  Loan_Status        541 non-null    object
# dtypes: float64(4), int64(2), object(6)
# memory usage: 71.1+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 333 entries, 0 to 366
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             333 non-null    object
#  1   Married            333 non-null    object
#  2   Dependents         333 non-null    int64
#  3   Education          333 non-null    object
#  4   Self_Employed      333 non-null    object
#  5   ApplicantIncome    333 non-null    int64
#  6   CoapplicantIncome  333 non-null    int64
#  7   LoanAmount         333 non-null    float64
#  8   Loan_Amount_Term   333 non-null    float64
#  9   Credit_History     333 non-null    float64
#  10  Property_Area      333 non-null    object
# dtypes: float64(3), int64(3), object(5)
# memory usage: 31.2+ KB

# %%
train_num=train.select_dtypes(include = np.number)

# %%
train_num
# Out:
#      Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 1             1             4583             1508.0       128.0
# 2             0             3000                0.0        66.0
# 3             0             2583             2358.0       120.0
# 4             0             6000                0.0       141.0
# 5             2             5417             4196.0       267.0
# ..          ...              ...                ...         ...
# 609           0             2900                0.0        71.0
# 610           3             4106                0.0        40.0
# 611           1             8072              240.0       253.0
# 612           2             7583                0.0       187.0
# 613           0             4583                0.0       133.0
#
#      Loan_Amount_Term  Credit_History
# 1               360.0             1.0
# 2               360.0             1.0
# 3               360.0             1.0
# 4               360.0             1.0
# ...

# %%
test_num=test.select_dtypes(include = np.number)

# %%
test_num
# Out:
#      Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0             0             5720                  0       110.0
# 1             1             3076               1500       126.0
# 2             2             5000               1800       208.0
# 4             0             3276                  0        78.0
# 5             0             2165               3422       152.0
# ..          ...              ...                ...         ...
# 361           1             2269               2167        99.0
# 362           3             4009               1777       113.0
# 363           0             4158                709       115.0
# 365           0             5000               2393       158.0
# 366           0             9200                  0        98.0
#
#      Loan_Amount_Term  Credit_History
# 0               360.0             1.0
# 1               360.0             1.0
# 2               360.0             1.0
# 4               360.0             1.0
# ...

# %%
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler, StandardScaler

# %%
scaling = MinMaxScaler()

# %%
# sklearn onehot
train_min_max=pd.DataFrame(scaling.fit_transform(train_num), columns = train_num.columns )

# %%
scaling = StandardScaler()
train_scale = pd.DataFrame(scaling.fit_transform(train_num), columns = train_num.columns )

# %%
test_scale=pd.DataFrame(scaling.fit_transform(test_num), columns = test_num.columns )

# %%
train_scale
# Out:
#      Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0      0.241569        -0.141051          -0.017397   -0.204324
# 1     -0.741054        -0.390889          -0.619179   -0.947889
# 2     -0.741054        -0.456703           0.321804   -0.300268
# 3     -0.741054         0.082588          -0.619179   -0.048415
# 4      1.224193        -0.009424           1.055275    1.462701
# ..          ...              ...                ...         ...
# 536   -0.741054        -0.406672          -0.619179   -0.887924
# 537    2.206816        -0.216334          -0.619179   -1.259707
# 538    0.241569         0.409603          -0.523405    1.294799
# 539    1.224193         0.332426          -0.619179    0.503262
# 540   -0.741054        -0.141051          -0.619179   -0.144359
#
#      Loan_Amount_Term  Credit_History
# 0            0.273695        0.431745
# 1            0.273695        0.431745
# 2            0.273695        0.431745
# 3            0.273695        0.431745
# ...

# %%
test_scale
# Out:
#      Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0     -0.761130         0.201334          -0.668038   -0.451727
# 1      0.184602        -0.346186          -0.010695   -0.177947
# 2      1.130335         0.052236           0.120773    1.225177
# 3     -0.761130        -0.304770          -0.668038   -0.999288
# 4     -0.761130        -0.534836           0.831580    0.266946
# ..          ...              ...                ...         ...
# 328    0.184602        -0.513300           0.281603   -0.639951
# 329    2.076068        -0.152980           0.110694   -0.400394
# 330   -0.761130        -0.122125          -0.357334   -0.366171
# 331   -0.761130         0.052236           0.380643    0.369614
# 332   -0.761130         0.921973          -0.668038   -0.657063
#
#      Loan_Amount_Term  Credit_History
# 0            0.277302        0.459248
# 1            0.277302        0.459248
# 2            0.277302        0.459248
# 3            0.277302        0.459248
# ...

# %%
train_min_max
# Out:
#      Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0      0.333333         0.054830           0.044567    0.172214
# 1      0.000000         0.035250           0.000000    0.082489
# 2      0.000000         0.030093           0.069687    0.160637
# 3      0.000000         0.072356           0.000000    0.191027
# 4      0.666667         0.065145           0.124006    0.373372
# ..          ...              ...                ...         ...
# 536    0.000000         0.034014           0.000000    0.089725
# 537    1.000000         0.048930           0.000000    0.044863
# 538    0.333333         0.097984           0.007093    0.353111
# 539    0.666667         0.091936           0.000000    0.257598
# 540    0.000000         0.054830           0.000000    0.179450
#
#      Loan_Amount_Term  Credit_History
# 0            0.729730             1.0
# 1            0.729730             1.0
# 2            0.729730             1.0
# 3            0.729730             1.0
# ...

# %%
test_min_max=pd.DataFrame(scaling.fit_transform(test_num), columns = test_num.columns )

# %%
test_min_max
# Out:
#      Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0     -0.761130         0.201334          -0.668038   -0.451727
# 1      0.184602        -0.346186          -0.010695   -0.177947
# 2      1.130335         0.052236           0.120773    1.225177
# 3     -0.761130        -0.304770          -0.668038   -0.999288
# 4     -0.761130        -0.534836           0.831580    0.266946
# ..          ...              ...                ...         ...
# 328    0.184602        -0.513300           0.281603   -0.639951
# 329    2.076068        -0.152980           0.110694   -0.400394
# 330   -0.761130        -0.122125          -0.357334   -0.366171
# 331   -0.761130         0.052236           0.380643    0.369614
# 332   -0.761130         0.921973          -0.668038   -0.657063
#
#      Loan_Amount_Term  Credit_History
# 0            0.277302        0.459248
# 1            0.277302        0.459248
# 2            0.277302        0.459248
# 3            0.277302        0.459248
# ...

# %%
train_cat1 = train.select_dtypes(exclude = np.number)

# %%
test_cat = test.select_dtypes(exclude = np.number)

# %%
test.select_dtypes(exclude = np.number)
# Out:
#     Gender Married     Education Self_Employed Property_Area
# 0     Male     Yes      Graduate            No         Urban
# 1     Male     Yes      Graduate            No         Urban
# 2     Male     Yes      Graduate            No         Urban
# 4     Male      No  Not Graduate            No         Urban
# 5     Male     Yes  Not Graduate           Yes         Urban
# ..     ...     ...           ...           ...           ...
# 361   Male     Yes      Graduate            No     Semiurban
# 362   Male     Yes  Not Graduate           Yes         Urban
# 363   Male     Yes      Graduate            No         Urban
# 365   Male     Yes      Graduate            No         Rural
# 366   Male      No      Graduate           Yes         Rural
#
# [333 rows x 5 columns]

# %%
train_cat=train.select_dtypes(exclude = np.number)

# %%
train.head(3)
# Out:
#   Gender Married  Dependents     Education Self_Employed  ApplicantIncome  \
# 1   Male     Yes           1      Graduate            No             4583
# 2   Male     Yes           0      Graduate           Yes             3000
# 3   Male     Yes           0  Not Graduate            No             2583
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
#
#   Property_Area Loan_Status
# 1         Rural           N
# 2         Urban           Y
# 3         Urban           Y

# %%
train_cat1=train_cat

# %%
train_cat
# Out:
#      Gender Married     Education Self_Employed Property_Area Loan_Status
# 1      Male     Yes      Graduate            No         Rural           N
# 2      Male     Yes      Graduate           Yes         Urban           Y
# 3      Male     Yes  Not Graduate            No         Urban           Y
# 4      Male      No      Graduate            No         Urban           Y
# 5      Male     Yes      Graduate           Yes         Urban           Y
# ..      ...     ...           ...           ...           ...         ...
# 609  Female      No      Graduate            No         Rural           Y
# 610    Male     Yes      Graduate            No         Rural           Y
# 611    Male     Yes      Graduate            No         Urban           Y
# 612    Male     Yes      Graduate            No         Urban           Y
# 613  Female      No      Graduate           Yes     Semiurban           N
#
# [541 rows x 6 columns]

# %%
test_cat
# Out:
#     Gender Married     Education Self_Employed Property_Area
# 0     Male     Yes      Graduate            No         Urban
# 1     Male     Yes      Graduate            No         Urban
# 2     Male     Yes      Graduate            No         Urban
# 4     Male      No  Not Graduate            No         Urban
# 5     Male     Yes  Not Graduate           Yes         Urban
# ..     ...     ...           ...           ...           ...
# 361   Male     Yes      Graduate            No     Semiurban
# 362   Male     Yes  Not Graduate           Yes         Urban
# 363   Male     Yes      Graduate            No         Urban
# 365   Male     Yes      Graduate            No         Rural
# 366   Male      No      Graduate           Yes         Rural
#
# [333 rows x 5 columns]

# %%
train_cat = pd.get_dummies(train_cat[['Gender','Married','Education','Self_Employed','Property_Area']])

# %%
test_cat = pd.get_dummies(test_cat[['Gender','Married','Education','Self_Employed','Property_Area']])

# %%
train_scale = train_scale.reset_index().drop(columns = 'index')
train_cat = train_cat.reset_index().drop(columns = 'index')

# %%
train_PP=pd.concat([train_scale,train_cat], axis = 1)

# %%
test_scale = test_scale.reset_index().drop(columns = 'index')
test_cat = test_cat.reset_index().drop(columns = 'index')

# %%
test_PP=pd.concat([test_scale,test_cat], axis = 1)

# %%
train_PP
# Out:
#      Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0      0.241569        -0.141051          -0.017397   -0.204324
# 1     -0.741054        -0.390889          -0.619179   -0.947889
# 2     -0.741054        -0.456703           0.321804   -0.300268
# 3     -0.741054         0.082588          -0.619179   -0.048415
# 4      1.224193        -0.009424           1.055275    1.462701
# ..          ...              ...                ...         ...
# 536   -0.741054        -0.406672          -0.619179   -0.887924
# 537    2.206816        -0.216334          -0.619179   -1.259707
# 538    0.241569         0.409603          -0.523405    1.294799
# 539    1.224193         0.332426          -0.619179    0.503262
# 540   -0.741054        -0.141051          -0.619179   -0.144359
#
#      Loan_Amount_Term  Credit_History  Gender_Female  Gender_Male  Married_No  \
# 0            0.273695        0.431745              0            1           0
# ...

# %%
test_PP
# Out:
#      Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0     -0.761130         0.201334          -0.668038   -0.451727
# 1      0.184602        -0.346186          -0.010695   -0.177947
# 2      1.130335         0.052236           0.120773    1.225177
# 3     -0.761130        -0.304770          -0.668038   -0.999288
# 4     -0.761130        -0.534836           0.831580    0.266946
# ..          ...              ...                ...         ...
# 328    0.184602        -0.513300           0.281603   -0.639951
# 329    2.076068        -0.152980           0.110694   -0.400394
# 330   -0.761130        -0.122125          -0.357334   -0.366171
# 331   -0.761130         0.052236           0.380643    0.369614
# 332   -0.761130         0.921973          -0.668038   -0.657063
#
#      Loan_Amount_Term  Credit_History  Gender_Female  Gender_Male  Married_No  \
# 0            0.277302        0.459248              0            1           0
# ...

# %%
train_X = train_PP
train_y = train['Loan_Status']

# %%
test_X=test_PP

# %%
model = LogisticRegression()

# %%
model.fit(train_X,train_y)
# Out:
# LogisticRegression()

# %%
model.fit(train_X,train_y)
# Out:
# LogisticRegression()

# %%
train_pred = model.predict(train_X)

# %%
train_pred
# Out:
# array(['Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'N', 'Y', 'Y', 'N', 'Y', 'N', 'N', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'N', 'N', 'Y', 'N', 'Y', 'Y', 'N', 'Y', 'Y',
#        'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'N', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N',
#        'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N',
#        'Y', 'N', 'N', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y',
# ...

# %%
test_pred = model.predict(test_X)

# %%
test_pred
# Out:
# array(['Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'N', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y',
#        'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'N', 'N', 'Y', 'N',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'N', 'Y',
#        'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'N', 'N', 'N', 'Y', 'Y', 'Y', 'N', 'N', 'Y', 'N', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y',
#        'N', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'N', 'N', 'Y', 'N', 'Y',
#        'Y', 'Y', 'Y', 'N', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
# ...

# %%
model.predict_proba(train_X)
# Out:
# array([[0.20175164, 0.79824836],
#        [0.19397154, 0.80602846],
#        [0.26008337, 0.73991663],
#        ...,
#        [0.20503481, 0.79496519],
#        [0.16551006, 0.83448994],
#        [0.92414008, 0.07585992]])

# %%
print("Train Result")
print(confusion_matrix(train_y, train_pred))
print(accuracy_score(train_y, train_pred))
# Out:
# Train Result
# [[ 79  90]
#  [  7 365]]
# 0.8207024029574861

# %%
print(accuracy_score(train_y, train_pred))
# Out:
# 0.8207024029574861

# %%
print(classification_report(train_y, train_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 print(classification_report(train_y, train_pred))
#
# NameError: name 'train_y' is not defined

# %%
print(classification_report(train_y, test_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 print(classification_report(train_y, test_pred))
#
# NameError: name 'classification_report' is not defined
